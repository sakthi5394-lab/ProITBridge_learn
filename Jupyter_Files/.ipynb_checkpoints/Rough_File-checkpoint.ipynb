# %% [markdown]
# ### List Comphrehension

# %%
even_li = [i for i in range(11) if i%2 == 0]
print(even_li)
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
print(__name__)
# Out:
# __main__

# %%
def var_twice(i,lst=[]):
    lst.append(i)
    lst.append(i)
    return lst

print(var_twice(1))
print(var_twice(2))
# Out:
# [1, 1]
# [1, 1, 2, 2]
