# %% [markdown]
# # Problem Statement
#
# ### Build a ML Model that predicts the median house price based on 13 socio-economic and property-related features from the Boston Housing dataset.

# %% [markdown]
# ## 1. Import Necessary Libraries

# %%
import numpy as np
from tensorflow.keras.datasets import boston_housing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### 2. Import Dataset

# %%
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()

# %% [markdown]
# ### 3. Data Understanding

# %%
X_train.shape,y_train.shape
# Out:
# ((404, 13), (404,))

# %%
X_test.shape,y_test.shape
# Out:
# ((102, 13), (102,))

# %% [markdown]
# ### 4. Data Preparation

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train.std().round(),X_train.mean().round()
# Out:
# (np.float64(1.0), np.float64(0.0))

# %%
X_test.std().round(),X_test.mean().round()
# Out:
# (np.float64(1.0), np.float64(-0.0))

# %% [markdown]
# ### 5. Model Building

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(13,))) #For structured data, use input_shape
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output layer (IMPORTANT)
model.add(Dense(1,))  # No activation → regression

# %%
model.compile(optimizer='adam',loss='mse', metrics=['mae'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ### 6. Model Training || 7. Model Testing || 8. Model Evaluation

# %%
model.fit(X_train, y_train,epochs=100,batch_size=16,validation_split=0.2, verbose=2)
# Out:
# Epoch 1/100
# 21/21 - 0s - 8ms/step - loss: 56.3026 - mae: 5.3608 - val_loss: 70.0133 - val_mae: 5.4947
# Epoch 2/100
# 21/21 - 0s - 16ms/step - loss: 55.8513 - mae: 5.0985 - val_loss: 69.0628 - val_mae: 5.5564
# Epoch 3/100
# 21/21 - 0s - 6ms/step - loss: 55.6646 - mae: 5.1106 - val_loss: 68.8598 - val_mae: 5.5792
# Epoch 4/100
# 21/21 - 0s - 8ms/step - loss: 55.6947 - mae: 5.1133 - val_loss: 68.6000 - val_mae: 5.6356
# Epoch 5/100
# 21/21 - 0s - 9ms/step - loss: 56.4234 - mae: 5.5134 - val_loss: 69.3899 - val_mae: 5.5358
# Epoch 6/100
# 21/21 - 0s - 10ms/step - loss: 56.4084 - mae: 5.0378 - val_loss: 68.8316 - val_mae: 5.5750
# Epoch 7/100
# 21/21 - 0s - 8ms/step - loss: 56.1739 - mae: 5.3929 - val_loss: 68.7388 - val_mae: 5.5899
# Epoch 8/100
# 21/21 - 0s - 15ms/step - loss: 55.8651 - mae: 5.0709 - val_loss: 68.3437 - val_mae: 5.6614
# Epoch 9/100
# 21/21 - 0s - 7ms/step - loss: 55.4126 - mae: 5.2297 - val_loss: 68.9885 - val_mae: 5.5528
# Epoch 10/100
# 21/21 - 0s - 9ms/step - loss: 55.5723 - mae: 5.0397 - val_loss: 67.8323 - val_mae: 5.7235
# Epoch 11/100
# 21/21 - 0s - 7ms/step - loss: 57.4295 - mae: 5.7313 - val_loss: 68.3416 - val_mae: 5.5702
# Epoch 12/100
# 21/21 - 0s - 7ms/step - loss: 55.2753 - mae: 4.9692 - val_loss: 69.0997 - val_mae: 5.4828
# Epoch 13/100
# 21/21 - 0s - 9ms/step - loss: 55.3797 - mae: 5.0666 - val_loss: 68.0722 - val_mae: 5.6025
# Epoch 14/100
# 21/21 - 0s - 9ms/step - loss: 55.1696 - mae: 5.1441 - val_loss: 69.6199 - val_mae: 5.4552
# Epoch 15/100
# 21/21 - 0s - 15ms/step - loss: 55.1386 - mae: 5.1165 - val_loss: 68.3231 - val_mae: 5.5487
# Epoch 16/100
# 21/21 - 0s - 6ms/step - loss: 54.8995 - mae: 5.0897 - val_loss: 68.6216 - val_mae: 5.4957
# Epoch 17/100
# 21/21 - 0s - 7ms/step - loss: 55.1365 - mae: 5.0974 - val_loss: 67.8046 - val_mae: 5.6059
# Epoch 18/100
# 21/21 - 0s - 9ms/step - loss: 55.2802 - mae: 5.1327 - val_loss: 67.5671 - val_mae: 5.6210
# Epoch 19/100
# 21/21 - 0s - 10ms/step - loss: 55.2356 - mae: 5.1067 - val_loss: 68.5095 - val_mae: 5.4842
# Epoch 20/100
# 21/21 - 0s - 9ms/step - loss: 54.8081 - mae: 5.0155 - val_loss: 67.5979 - val_mae: 5.5687
# Epoch 21/100
# 21/21 - 0s - 7ms/step - loss: 54.7916 - mae: 5.1009 - val_loss: 67.4716 - val_mae: 5.5707
# Epoch 22/100
# 21/21 - 0s - 6ms/step - loss: 54.5573 - mae: 5.0700 - val_loss: 68.1365 - val_mae: 5.4868
# Epoch 23/100
# 21/21 - 0s - 7ms/step - loss: 55.1931 - mae: 5.1904 - val_loss: 68.4747 - val_mae: 5.4571
# Epoch 24/100
# 21/21 - 0s - 6ms/step - loss: 54.5793 - mae: 5.0336 - val_loss: 67.8136 - val_mae: 5.5045
# Epoch 25/100
# 21/21 - 0s - 8ms/step - loss: 55.0258 - mae: 5.2574 - val_loss: 68.9480 - val_mae: 5.4085
# Epoch 26/100
# 21/21 - 0s - 9ms/step - loss: 54.5853 - mae: 4.9495 - val_loss: 67.6655 - val_mae: 5.4982
# Epoch 27/100
# 21/21 - 0s - 9ms/step - loss: 54.5844 - mae: 5.1490 - val_loss: 67.8291 - val_mae: 5.4677
# Epoch 28/100
# 21/21 - 0s - 6ms/step - loss: 54.5651 - mae: 5.0427 - val_loss: 68.5791 - val_mae: 5.3961
# Epoch 29/100
# 21/21 - 0s - 8ms/step - loss: 54.3022 - mae: 4.9860 - val_loss: 66.9321 - val_mae: 5.5634
# Epoch 30/100
# 21/21 - 0s - 19ms/step - loss: 53.9775 - mae: 5.1186 - val_loss: 68.5686 - val_mae: 5.4163
# Epoch 31/100
# 21/21 - 0s - 13ms/step - loss: 54.1373 - mae: 4.9774 - val_loss: 67.5113 - val_mae: 5.4887
# Epoch 32/100
# 21/21 - 0s - 8ms/step - loss: 54.1533 - mae: 5.0593 - val_loss: 67.7969 - val_mae: 5.4399
# Epoch 33/100
# 21/21 - 0s - 15ms/step - loss: 54.6316 - mae: 5.0704 - val_loss: 67.1518 - val_mae: 5.5096
# Epoch 34/100
# 21/21 - 0s - 6ms/step - loss: 54.0551 - mae: 4.9809 - val_loss: 67.0417 - val_mae: 5.5049
# Epoch 35/100
# 21/21 - 0s - 6ms/step - loss: 53.8485 - mae: 5.1296 - val_loss: 67.6859 - val_mae: 5.4247
# Epoch 36/100
# 21/21 - 0s - 10ms/step - loss: 53.7172 - mae: 5.0561 - val_loss: 67.4448 - val_mae: 5.4481
# Epoch 37/100
# 21/21 - 0s - 6ms/step - loss: 53.8175 - mae: 4.9597 - val_loss: 66.9614 - val_mae: 5.4854
# Epoch 38/100
# 21/21 - 0s - 8ms/step - loss: 53.8128 - mae: 4.9809 - val_loss: 67.2422 - val_mae: 5.4470
# Epoch 39/100
# 21/21 - 0s - 15ms/step - loss: 54.2479 - mae: 4.9959 - val_loss: 66.7733 - val_mae: 5.4941
# Epoch 40/100
# 21/21 - 0s - 9ms/step - loss: 53.6602 - mae: 5.1079 - val_loss: 67.9730 - val_mae: 5.3704
# Epoch 41/100
# 21/21 - 0s - 17ms/step - loss: 54.1435 - mae: 4.8306 - val_loss: 66.1212 - val_mae: 5.5811
# Epoch 42/100
# 21/21 - 0s - 14ms/step - loss: 54.2939 - mae: 5.1123 - val_loss: 67.6405 - val_mae: 5.3929
# Epoch 43/100
# 21/21 - 0s - 7ms/step - loss: 54.2649 - mae: 5.2670 - val_loss: 67.5001 - val_mae: 5.3768
# Epoch 44/100
# 21/21 - 0s - 7ms/step - loss: 55.8197 - mae: 4.8519 - val_loss: 66.1857 - val_mae: 5.5103
# Epoch 45/100
# 21/21 - 0s - 6ms/step - loss: 54.1029 - mae: 5.2700 - val_loss: 68.1311 - val_mae: 5.3514
# Epoch 46/100
# 21/21 - 0s - 8ms/step - loss: 53.5042 - mae: 4.9735 - val_loss: 67.3540 - val_mae: 5.3779
# Epoch 47/100
# 21/21 - 0s - 8ms/step - loss: 53.5317 - mae: 4.9641 - val_loss: 68.4303 - val_mae: 5.3072
# Epoch 48/100
# 21/21 - 0s - 9ms/step - loss: 53.4197 - mae: 5.0206 - val_loss: 66.5056 - val_mae: 5.4150
# Epoch 49/100
# 21/21 - 0s - 8ms/step - loss: 53.1466 - mae: 4.9393 - val_loss: 66.1654 - val_mae: 5.4376
# Epoch 50/100
# 21/21 - 0s - 8ms/step - loss: 53.3068 - mae: 4.8616 - val_loss: 65.8253 - val_mae: 5.4826
# Epoch 51/100
# 21/21 - 0s - 8ms/step - loss: 53.2467 - mae: 5.2043 - val_loss: 66.2448 - val_mae: 5.4092
# Epoch 52/100
# 21/21 - 0s - 15ms/step - loss: 52.7409 - mae: 4.8668 - val_loss: 66.1802 - val_mae: 5.4124
# Epoch 53/100
# 21/21 - 0s - 8ms/step - loss: 53.2288 - mae: 5.1758 - val_loss: 65.7917 - val_mae: 5.4382
# Epoch 54/100
# 21/21 - 0s - 14ms/step - loss: 52.5466 - mae: 4.9600 - val_loss: 66.9056 - val_mae: 5.3247
# Epoch 55/100
# 21/21 - 0s - 9ms/step - loss: 53.1320 - mae: 4.8408 - val_loss: 65.4087 - val_mae: 5.4798
# Epoch 56/100
# 21/21 - 0s - 10ms/step - loss: 52.6232 - mae: 5.0001 - val_loss: 65.9060 - val_mae: 5.3941
# Epoch 57/100
# 21/21 - 0s - 14ms/step - loss: 52.4257 - mae: 4.9588 - val_loss: 66.4243 - val_mae: 5.3339
# Epoch 58/100
# 21/21 - 0s - 7ms/step - loss: 52.7616 - mae: 4.8529 - val_loss: 64.9845 - val_mae: 5.4978
# Epoch 59/100
# 21/21 - 0s - 7ms/step - loss: 53.1405 - mae: 5.0400 - val_loss: 65.5314 - val_mae: 5.4075
# Epoch 60/100
# 21/21 - 0s - 11ms/step - loss: 53.5100 - mae: 4.8993 - val_loss: 64.6357 - val_mae: 5.5773
# Epoch 61/100
# 21/21 - 0s - 13ms/step - loss: 52.6259 - mae: 5.0460 - val_loss: 66.3579 - val_mae: 5.2978
# Epoch 62/100
# 21/21 - 0s - 7ms/step - loss: 52.6594 - mae: 4.9235 - val_loss: 65.2080 - val_mae: 5.3969
# Epoch 63/100
# 21/21 - 0s - 7ms/step - loss: 52.0693 - mae: 4.9910 - val_loss: 67.1543 - val_mae: 5.2444
# Epoch 64/100
# 21/21 - 0s - 6ms/step - loss: 52.0888 - mae: 4.8529 - val_loss: 64.7431 - val_mae: 5.4261
# Epoch 65/100
# 21/21 - 0s - 9ms/step - loss: 51.6072 - mae: 4.9470 - val_loss: 67.0314 - val_mae: 5.2375
# Epoch 66/100
# 21/21 - 0s - 7ms/step - loss: 52.3555 - mae: 4.8531 - val_loss: 64.6943 - val_mae: 5.3965
# Epoch 67/100
# 21/21 - 0s - 9ms/step - loss: 51.6451 - mae: 4.7842 - val_loss: 65.3037 - val_mae: 5.3141
# Epoch 68/100
# 21/21 - 0s - 8ms/step - loss: 51.8051 - mae: 4.9152 - val_loss: 64.5393 - val_mae: 5.3752
# Epoch 69/100
# 21/21 - 0s - 14ms/step - loss: 51.5655 - mae: 4.7889 - val_loss: 64.3373 - val_mae: 5.3852
# Epoch 70/100
# 21/21 - 0s - 9ms/step - loss: 51.2837 - mae: 4.9975 - val_loss: 65.7697 - val_mae: 5.2447
# Epoch 71/100
# 21/21 - 0s - 7ms/step - loss: 51.4259 - mae: 4.8258 - val_loss: 63.8024 - val_mae: 5.4124
# Epoch 72/100
# 21/21 - 0s - 9ms/step - loss: 51.0471 - mae: 4.9602 - val_loss: 64.7044 - val_mae: 5.2862
# Epoch 73/100
# 21/21 - 0s - 7ms/step - loss: 51.1047 - mae: 4.9077 - val_loss: 64.8569 - val_mae: 5.2609
# Epoch 74/100
# 21/21 - 0s - 7ms/step - loss: 51.5719 - mae: 4.7596 - val_loss: 63.1150 - val_mae: 5.5593
# Epoch 75/100
# 21/21 - 0s - 10ms/step - loss: 53.2556 - mae: 5.1128 - val_loss: 65.6634 - val_mae: 5.1916
# Epoch 76/100
# 21/21 - 0s - 15ms/step - loss: 51.4497 - mae: 4.9253 - val_loss: 64.3639 - val_mae: 5.2396
# Epoch 77/100
# 21/21 - 0s - 8ms/step - loss: 53.1986 - mae: 5.2382 - val_loss: 67.3941 - val_mae: 5.1330
# Epoch 78/100
# 21/21 - 0s - 6ms/step - loss: 51.5508 - mae: 4.7875 - val_loss: 63.2497 - val_mae: 5.3014
# Epoch 79/100
# 21/21 - 0s - 5ms/step - loss: 50.5262 - mae: 4.8927 - val_loss: 63.1647 - val_mae: 5.3062
# Epoch 80/100
# 21/21 - 0s - 8ms/step - loss: 51.9726 - mae: 4.6473 - val_loss: 62.3145 - val_mae: 5.5935
# Epoch 81/100
# 21/21 - 0s - 7ms/step - loss: 51.7400 - mae: 5.0940 - val_loss: 65.6317 - val_mae: 5.1393
# Epoch 82/100
# 21/21 - 0s - 6ms/step - loss: 50.1146 - mae: 4.7916 - val_loss: 62.7325 - val_mae: 5.2831
# Epoch 83/100
# 21/21 - 0s - 8ms/step - loss: 50.5989 - mae: 5.1474 - val_loss: 68.5641 - val_mae: 5.1138
# Epoch 84/100
# 21/21 - 0s - 6ms/step - loss: 51.3039 - mae: 4.6202 - val_loss: 62.0157 - val_mae: 5.3293
# Epoch 85/100
# 21/21 - 0s - 6ms/step - loss: 50.1296 - mae: 4.8853 - val_loss: 62.7140 - val_mae: 5.2132
# Epoch 86/100
# 21/21 - 0s - 7ms/step - loss: 49.6051 - mae: 4.6353 - val_loss: 61.5571 - val_mae: 5.3218
# Epoch 87/100
# 21/21 - 0s - 6ms/step - loss: 49.8893 - mae: 4.9414 - val_loss: 62.9809 - val_mae: 5.1567
# Epoch 88/100
# 21/21 - 0s - 6ms/step - loss: 49.7361 - mae: 4.8669 - val_loss: 63.4781 - val_mae: 5.1180
# Epoch 89/100
# 21/21 - 0s - 9ms/step - loss: 49.1957 - mae: 4.6764 - val_loss: 61.9335 - val_mae: 5.1916
# Epoch 90/100
# 21/21 - 0s - 6ms/step - loss: 49.6680 - mae: 4.8962 - val_loss: 63.5359 - val_mae: 5.0888
# Epoch 91/100
# 21/21 - 0s - 6ms/step - loss: 49.1678 - mae: 4.8766 - val_loss: 62.3916 - val_mae: 5.1187
# Epoch 92/100
# 21/21 - 0s - 6ms/step - loss: 50.1002 - mae: 4.9460 - val_loss: 66.2676 - val_mae: 5.0470
# Epoch 93/100
# 21/21 - 0s - 9ms/step - loss: 48.5742 - mae: 4.6651 - val_loss: 60.1133 - val_mae: 5.3978
# Epoch 94/100
# 21/21 - 0s - 7ms/step - loss: 49.4742 - mae: 4.6651 - val_loss: 60.2224 - val_mae: 5.2544
# Epoch 95/100
# 21/21 - 0s - 6ms/step - loss: 48.5873 - mae: 4.9509 - val_loss: 63.7663 - val_mae: 5.0293
# Epoch 96/100
# 21/21 - 0s - 8ms/step - loss: 47.9704 - mae: 4.4931 - val_loss: 59.7239 - val_mae: 5.4690
# Epoch 97/100
# 21/21 - 0s - 6ms/step - loss: 49.1159 - mae: 4.8383 - val_loss: 61.4991 - val_mae: 5.0710
# Epoch 98/100
# 21/21 - 0s - 6ms/step - loss: 48.1466 - mae: 4.6965 - val_loss: 59.3541 - val_mae: 5.3526
# Epoch 99/100
# 21/21 - 0s - 8ms/step - loss: 48.0065 - mae: 4.7876 - val_loss: 62.3904 - val_mae: 5.0242
# Epoch 100/100
# 21/21 - 0s - 8ms/step - loss: 48.4484 - mae: 4.6742 - val_loss: 60.7454 - val_mae: 5.0626

# %% [markdown]
# ### 9. Model Prediction (New Observation)

# %%
# Example new data (13 features)
new_data = np.array([[0.02, 18, 2.5, 0, 0.45, 6.5, 65, 4.5, 1, 300, 15, 390, 5]])

# Apply same scaling
new_data = scaler.transform(new_data)

# Predict
prediction = model.predict(new_data)

print("Predicted House Price:", prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted House Price: [[26.323103]]

# %% [markdown]
# # THE END!
