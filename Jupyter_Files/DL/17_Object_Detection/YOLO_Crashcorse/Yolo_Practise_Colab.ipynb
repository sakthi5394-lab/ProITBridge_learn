# %%
# !pip install ultralytics

# %%
# Clone the YOLOv3 repository
# !git clone https://github.com/ultralytics/yolov3
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 13074, done.
# remote: Counting objects: 100% (521/521), done.
# remote: Compressing objects: 100% (313/313), done.
# remote: Total 13074 (delta 387), reused 226 (delta 208), pack-reused 12553 (from 3)
# Receiving objects: 100% (13074/13074), 11.35 MiB | 27.80 MiB/s, done.
# Resolving deltas: 100% (8844/8844), done.

# %%
# %cd
# Out:
# /root

# %%
# %cd /content/yolov3
# Out:
# /content/yolov3

# %%
pip install -r requirements.txt

# %%
import torch

# Load a YOLOv3 model (choices: 'yolov3', 'yolov3_spp', 'yolov3_tiny')
model = torch.hub.load("ultralytics/yolov3", "yolov3", pretrained=True)
# Out:
# The repository ultralytics_yolov3 does not belong to the list of trusted repositories and as such cannot be downloaded. Do you trust this repository and wish to add it to the trusted list of repositories (y/N)?y
# Downloading: "https://github.com/ultralytics/yolov3/zipball/master" to /root/.cache/torch/hub/master.zip
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv3 🚀 2026-8-13 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# ...
# 100%|██████████| 119M/119M [00:02<00:00, 45.4MB/s]
# Fusing layers...
# YOLOv3 summary: 151 layers, 61,922,845 parameters, 0 gradients, 155.9 GFLOPs
# Adding AutoShape...

# %%
# !python detect.py --weights yolov3.pt --source /content/Bangalore-traffic.jpg
# Out:
# detect: agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, data=data/coco128.yaml, device=, dnn=False, exist_ok=False, half=False, hide_conf=False, hide_labels=False, imgsz=[640, 640], iou_thres=0.45, line_thickness=3, max_det=1000, name=exp, nosave=False, project=runs/detect, save_conf=False, save_crop=False, save_txt=False, source=/content/Bangalore-traffic.jpg, update=False, vid_stride=1, view_img=False, visualize=False, weights=['yolov3.pt']
# YOLOv3 🚀 v9.6.0-356-g97b87b1 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# YOLOv3 summary: 151 layers, 61,922,845 parameters, 0 gradients, 155.9 GFLOPs
# image 1/1 /content/Bangalore-traffic.jpg: 320x640 16 persons, 3 cars, 10 motorcycles, 74.6ms
# Speed: 0.8ms pre-process, 74.6ms inference, 197.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
# !python detect.py --weights yolov3.pt --source /content/YTDown_YouTube_fast-motion-cars-moving-on-highway_Media_BLc8s-_tsiQ_004_360p.mp4
# Out:
# detect: agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, data=data/coco128.yaml, device=, dnn=False, exist_ok=False, half=False, hide_conf=False, hide_labels=False, imgsz=[640, 640], iou_thres=0.45, line_thickness=3, max_det=1000, name=exp, nosave=False, project=runs/detect, save_conf=False, save_crop=False, save_txt=False, source=/content/YTDown_YouTube_fast-motion-cars-moving-on-highway_Media_BLc8s-_tsiQ_004_360p.mp4, update=False, vid_stride=1, view_img=False, visualize=False, weights=['yolov3.pt']
# YOLOv3 🚀 v9.6.0-356-g97b87b1 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# YOLOv3 summary: 151 layers, 61,922,845 parameters, 0 gradients, 155.9 GFLOPs
# video 1/1 (1/922) /content/YTDown_YouTube_fast-motion-cars-moving-on-highway_Media_BLc8s-_tsiQ_004_360p.mp4: 384x640 37 cars, 2 trucks, 51.5ms
# ...
