# %% [markdown]
# # WebCam Detection & Prediction using YOLO
#
# **Note:**
# 1. This script is for Pre-defined Classes Prediction - Not for *Custom Data*
# 2. So take predefined Models - which has predefined weights for our prediction, but it will predict the same items.

# %%
#!pip install ultralytics

# %%
import cv2
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

video = cv2.VideoCapture(0)

while True:
    success, frame = video.read()
    if success == True:
        results = model(frame)
        print(results)
        
        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                confidence = float(box.conf[0])
                class_id = int(box.cls[0])
                class_name = model.names[class_id]
                cv2.rectangle(frame,(x1, y1),(x2, y2),(0, 255, 0),3)
                label = f"{class_name} {confidence:.2f}"
                cv2.putText(frame,label,(x1, y1 - 10),cv2.FONT_HERSHEY_SIMPLEX,0.7,(0, 255, 0),2) # Put Label Above Box

        cv2.imshow("YOLO Webcam Detection", frame)
        key = cv2.waitKey(delay = 1)
        if key == 113 or key == 81:
            break
   
    else:
        print("Video Stopped")

video.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 193.8ms
# Speed: 65.0ms preprocess, 193.8ms inference, 30.8ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 93,  95,  95],
#         [ 94,  96,  96],
#         [ 96,  98,  98],
#         ...,
#         [ 86,  85,  87],
#         [ 87,  86,  88],
#         [ 87,  86,  88]],
#
#        [[ 93,  95,  95],
#         [ 94,  96,  96],
#         [ 96,  98,  98],
#         ...,
#         [ 87,  86,  89],
#         [ 88,  87,  90],
#         [ 89,  88,  91]],
#
#        [[ 94,  96,  96],
#         [ 95,  97,  97],
#         [ 96,  98,  98],
#         ...,
#         [ 89,  88,  91],
#         [ 90,  89,  92],
#         [ 90,  89,  92]],
#
#        ...,
#
#        [[ 99, 171, 125],
#         [ 99, 171, 125],
#         [ 99, 171, 125],
#         ...,
#         [ 50,  43,  40],
#         [ 48,  41,  38],
#         [ 46,  39,  36]],
#
#        [[ 97, 169, 123],
#         [ 98, 170, 124],
#         [ 99, 171, 125],
#         ...,
#         [ 48,  41,  38],
#         [ 47,  40,  37],
#         [ 46,  39,  36]],
#
#        [[ 96, 168, 122],
#         [ 98, 170, 124],
#         [ 99, 171, 125],
#         ...,
#         [ 47,  40,  37],
#         [ 47,  40,  37],
#         [ 47,  40,  37]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 64.964700024575, 'inference': 193.80469992756844, 'postprocess': 30.823100125417113}]
#
# 0: 480x640 1 person, 49.4ms
# Speed: 1.2ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 83,  89,  88],
#         [ 82,  88,  87],
#         [ 81,  87,  86],
#         ...,
#         [ 48,  57,  61],
#         [ 43,  44,  51],
#         [ 40,  36,  44]],
#
#        [[ 82,  89,  88],
#         [ 83,  89,  88],
#         [ 83,  89,  88],
#         ...,
#         [ 38,  45,  48],
#         [ 38,  39,  44],
#         [ 40,  37,  43]],
#
#        [[ 81,  88,  87],
#         [ 82,  88,  87],
#         [ 84,  89,  88],
#         ...,
#         [ 39,  41,  42],
#         [ 40,  41,  42],
#         [ 42,  42,  43]],
#
#        ...,
#
#        [[ 88, 166, 125],
#         [ 89, 167, 126],
#         [ 89, 167, 126],
#         ...,
#         [ 49,  41,  39],
#         [ 49,  41,  40],
#         [ 52,  44,  44]],
#
#        [[ 88, 166, 122],
#         [ 89, 167, 123],
#         [ 89, 167, 124],
#         ...,
#         [ 49,  41,  41],
#         [ 50,  42,  42],
#         [ 52,  44,  44]],
#
#        [[ 90, 167, 122],
#         [ 91, 168, 123],
#         [ 91, 168, 124],
#         ...,
#         [ 52,  44,  44],
#         [ 52,  44,  44],
#         [ 52,  44,  44]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 1.2189000844955444, 'inference': 49.44059997797012, 'postprocess': 0.5272999405860901}]
#
# 0: 480x640 1 person, 61.8ms
# Speed: 1.8ms preprocess, 61.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 90,  90,  88],
#         [ 89,  90,  88],
#         [ 87,  90,  88],
#         ...,
#         [ 52,  50,  50],
#         [ 48,  45,  47],
#         [ 46,  43,  46]],
#
#        [[ 89,  90,  88],
#         [ 88,  90,  88],
#         [ 86,  90,  88],
#         ...,
#         [ 47,  45,  45],
#         [ 46,  43,  45],
#         [ 47,  44,  46]],
#
#        [[ 85,  88,  85],
#         [ 85,  89,  86],
#         [ 86,  90,  87],
#         ...,
#         [ 45,  42,  44],
#         [ 46,  43,  44],
#         [ 46,  44,  44]],
#
#        ...,
#
#        [[ 92, 168, 126],
#         [ 92, 168, 126],
#         [ 93, 169, 125],
#         ...,
#         [ 52,  49,  48],
#         [ 52,  49,  48],
#         [ 53,  49,  48]],
#
#        [[ 92, 167, 125],
#         [ 93, 168, 126],
#         [ 94, 169, 128],
#         ...,
#         [ 52,  48,  47],
#         [ 52,  48,  47],
#         [ 51,  47,  46]],
#
#        [[ 93, 167, 125],
#         [ 95, 169, 127],
#         [ 96, 169, 129],
#         ...,
#         [ 51,  47,  46],
#         [ 51,  47,  46],
#         [ 50,  46,  45]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 1.78829999640584, 'inference': 61.773400055244565, 'postprocess': 0.610999995842576}]
#
# 0: 480x640 1 person, 50.4ms
# Speed: 0.9ms preprocess, 50.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 82,  90,  94],
#         [ 82,  89,  92],
#         [ 81,  88,  90],
#         ...,
#         [ 50,  48,  54],
#         [ 49,  45,  51],
#         [ 46,  42,  47]],
#
#        [[ 83,  89,  91],
#         [ 81,  88,  90],
#         [ 81,  89,  89],
#         ...,
#         [ 49,  47,  51],
#         [ 48,  44,  49],
#         [ 47,  44,  47]],
#
#        [[ 83,  88,  88],
#         [ 83,  89,  89],
#         [ 83,  90,  90],
#         ...,
#         [ 46,  43,  45],
#         [ 46,  43,  45],
#         [ 47,  44,  46]],
#
#        ...,
#
#        [[ 93, 169, 124],
#         [ 94, 170, 126],
#         [ 92, 169, 125],
#         ...,
#         [ 53,  48,  49],
#         [ 53,  49,  48],
#         [ 53,  49,  47]],
#
#        [[ 92, 169, 125],
#         [ 94, 170, 126],
#         [ 94, 170, 126],
#         ...,
#         [ 53,  48,  47],
#         [ 52,  47,  45],
#         [ 51,  46,  43]],
#
#        [[ 91, 168, 124],
#         [ 93, 170, 125],
#         [ 95, 170, 125],
#         ...,
#         [ 54,  48,  46],
#         [ 52,  46,  43],
#         [ 50,  45,  41]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.893099932000041, 'inference': 50.356300082057714, 'postprocess': 0.6883998867124319}]
#
# 0: 480x640 1 person, 43.7ms
# Speed: 0.7ms preprocess, 43.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 82,  89,  88],
#         [ 82,  89,  88],
#         [ 82,  88,  90],
#         ...,
#         [ 51,  49,  52],
#         [ 49,  45,  48],
#         [ 49,  43,  47]],
#
#        [[ 83,  89,  88],
#         [ 84,  90,  89],
#         [ 84,  90,  90],
#         ...,
#         [ 49,  47,  50],
#         [ 48,  44,  46],
#         [ 48,  43,  45]],
#
#        [[ 84,  89,  88],
#         [ 85,  90,  89],
#         [ 86,  91,  89],
#         ...,
#         [ 46,  43,  45],
#         [ 46,  43,  45],
#         [ 47,  45,  45]],
#
#        ...,
#
#        [[ 92, 170, 126],
#         [ 93, 170, 126],
#         [ 94, 169, 127],
#         ...,
#         [ 54,  51,  50],
#         [ 53,  50,  49],
#         [ 53,  49,  48]],
#
#        [[ 93, 168, 127],
#         [ 94, 168, 127],
#         [ 95, 168, 126],
#         ...,
#         [ 54,  51,  50],
#         [ 53,  50,  49],
#         [ 52,  48,  47]],
#
#        [[ 95, 168, 129],
#         [ 96, 168, 129],
#         [ 96, 167, 127],
#         ...,
#         [ 51,  48,  47],
#         [ 51,  48,  47],
#         [ 50,  46,  45]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.7489998824894428, 'inference': 43.69409987702966, 'postprocess': 0.7780999876558781}]
#
# 0: 480x640 1 person, 48.1ms
# Speed: 0.7ms preprocess, 48.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 86,  91,  87],
#         [ 86,  91,  89],
#         [ 88,  93,  94],
#         ...,
#         [ 57,  58,  58],
#         [ 52,  50,  49],
#         [ 55,  51,  49]],
#
#        [[ 87,  92,  88],
#         [ 86,  91,  89],
#         [ 88,  93,  92],
#         ...,
#         [ 49,  50,  50],
#         [ 49,  47,  46],
#         [ 53,  49,  48]],
#
#        [[ 87,  91,  89],
#         [ 86,  91,  89],
#         [ 87,  92,  90],
#         ...,
#         [ 43,  43,  40],
#         [ 46,  43,  42],
#         [ 50,  45,  46]],
#
#        ...,
#
#        [[ 94, 171, 127],
#         [ 95, 172, 128],
#         [ 96, 173, 130],
#         ...,
#         [ 56,  51,  50],
#         [ 58,  53,  52],
#         [ 57,  52,  51]],
#
#        [[ 96, 172, 128],
#         [ 96, 172, 128],
#         [ 97, 172, 128],
#         ...,
#         [ 56,  51,  50],
#         [ 56,  50,  51],
#         [ 56,  50,  51]],
#
#        [[ 97, 172, 128],
#         [ 97, 172, 127],
#         [ 97, 172, 127],
#         ...,
#         [ 54,  49,  48],
#         [ 55,  49,  50],
#         [ 55,  49,  50]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.6960001774132252, 'inference': 48.08399989269674, 'postprocess': 0.6984001956880093}]
#
# 0: 480x640 1 person, 60.6ms
# Speed: 1.4ms preprocess, 60.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 87,  91,  90],
#         [ 86,  91,  90],
#         [ 87,  92,  93],
#         ...,
#         [ 59,  51,  55],
#         [ 54,  47,  49],
#         [ 54,  47,  48]],
#
#        [[ 88,  92,  91],
#         [ 87,  92,  91],
#         [ 87,  93,  93],
#         ...,
#         [ 55,  49,  51],
#         [ 52,  46,  47],
#         [ 53,  47,  48]],
#
#        [[ 87,  92,  90],
#         [ 87,  92,  90],
#         [ 88,  93,  92],
#         ...,
#         [ 49,  46,  45],
#         [ 51,  47,  46],
#         [ 52,  48,  47]],
#
#        ...,
#
#        [[ 95, 170, 132],
#         [ 94, 170, 131],
#         [ 94, 172, 132],
#         ...,
#         [ 54,  50,  52],
#         [ 54,  50,  51],
#         [ 54,  49,  50]],
#
#        [[ 94, 171, 130],
#         [ 93, 171, 130],
#         [ 92, 172, 130],
#         ...,
#         [ 53,  49,  50],
#         [ 54,  49,  49],
#         [ 56,  51,  50]],
#
#        [[ 93, 172, 129],
#         [ 93, 172, 129],
#         [ 92, 172, 129],
#         ...,
#         [ 54,  49,  50],
#         [ 54,  49,  48],
#         [ 56,  50,  48]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 1.3523001689463854, 'inference': 60.561199905350804, 'postprocess': 0.8048000745475292}]
#
# 0: 480x640 1 person, 51.0ms
# Speed: 1.4ms preprocess, 51.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 86,  90,  94],
#         [ 85,  90,  94],
#         [ 84,  92,  95],
#         ...,
#         [ 55,  48,  52],
#         [ 50,  43,  47],
#         [ 54,  46,  50]],
#
#        [[ 86,  92,  94],
#         [ 85,  92,  94],
#         [ 85,  93,  95],
#         ...,
#         [ 50,  44,  46],
#         [ 48,  42,  44],
#         [ 53,  47,  49]],
#
#        [[ 84,  94,  91],
#         [ 84,  94,  92],
#         [ 85,  93,  93],
#         ...,
#         [ 47,  42,  43],
#         [ 48,  44,  43],
#         [ 52,  48,  47]],
#
#        ...,
#
#        [[ 99, 170, 131],
#         [ 98, 171, 131],
#         [ 95, 172, 130],
#         ...,
#         [ 54,  51,  50],
#         [ 54,  51,  50],
#         [ 54,  50,  49]],
#
#        [[ 97, 169, 130],
#         [ 96, 171, 130],
#         [ 94, 171, 129],
#         ...,
#         [ 53,  50,  49],
#         [ 55,  51,  50],
#         [ 55,  51,  50]],
#
#        [[ 96, 169, 130],
#         [ 96, 171, 130],
#         [ 94, 172, 129],
#         ...,
#         [ 54,  50,  49],
#         [ 54,  50,  49],
#         [ 55,  51,  50]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 1.4325999654829502, 'inference': 50.985800102353096, 'postprocess': 0.526099931448698}]
#
# 0: 480x640 1 person, 56.4ms
# Speed: 1.2ms preprocess, 56.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 90,  94,  93],
#         [ 89,  94,  93],
#         [ 88,  95,  95],
#         ...,
#         [ 63,  57,  61],
#         [ 53,  50,  53],
#         [ 51,  49,  52]],
#
#        [[ 89,  93,  92],
#         [ 88,  93,  92],
#         [ 87,  94,  93],
#         ...,
#         [ 57,  53,  56],
#         [ 49,  46,  48],
#         [ 47,  45,  47]],
#
#        [[ 89,  93,  91],
#         [ 88,  93,  91],
#         [ 86,  94,  91],
#         ...,
#         [ 50,  47,  49],
#         [ 48,  46,  46],
#         [ 49,  48,  47]],
#
#        ...,
#
#        [[101, 171, 134],
#         [ 99, 172, 133],
#         [ 96, 172, 130],
#         ...,
#         [ 58,  52,  53],
#         [ 58,  52,  53],
#         [ 58,  52,  53]],
#
#        [[ 98, 172, 131],
#         [ 96, 172, 130],
#         [ 93, 172, 129],
#         ...,
#         [ 59,  54,  55],
#         [ 60,  54,  54],
#         [ 61,  55,  54]],
#
#        [[ 96, 173, 130],
#         [ 96, 174, 131],
#         [ 92, 173, 130],
#         ...,
#         [ 60,  56,  56],
#         [ 60,  55,  54],
#         [ 60,  54,  52]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 1.220199977979064, 'inference': 56.362400064244866, 'postprocess': 0.5019002128392458}]
#
# 0: 480x640 1 person, 1 tie, 51.1ms
# Speed: 0.6ms preprocess, 51.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 88,  93,  98],
#         [ 89,  94,  97],
#         [ 89,  95,  95],
#         ...,
#         [ 57,  59,  62],
#         [ 54,  53,  60],
#         [ 51,  47,  58]],
#
#        [[ 90,  95,  98],
#         [ 89,  94,  96],
#         [ 88,  94,  93],
#         ...,
#         [ 55,  57,  58],
#         [ 53,  51,  57],
#         [ 50,  46,  54]],
#
#        [[ 90,  94,  95],
#         [ 90,  95,  95],
#         [ 89,  94,  93],
#         ...,
#         [ 52,  52,  52],
#         [ 53,  50,  52],
#         [ 51,  47,  49]],
#
#        ...,
#
#        [[101, 173, 133],
#         [ 99, 173, 132],
#         [ 97, 173, 131],
#         ...,
#         [ 58,  55,  55],
#         [ 61,  56,  57],
#         [ 59,  54,  55]],
#
#        [[ 96, 174, 133],
#         [ 95, 173, 132],
#         [ 95, 173, 132],
#         ...,
#         [ 58,  54,  52],
#         [ 62,  57,  56],
#         [ 60,  55,  54]],
#
#        [[ 93, 175, 133],
#         [ 94, 175, 133],
#         [ 95, 174, 133],
#         ...,
#         [ 61,  58,  54],
#         [ 65,  60,  58],
#         [ 62,  56,  55]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.6428000051528215, 'inference': 51.12299998290837, 'postprocess': 0.7379001472145319}]
#
# 0: 480x640 1 person, 1 tie, 44.7ms
# Speed: 0.9ms preprocess, 44.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 88,  96,  96],
#         [ 90,  98,  99],
#         [ 90,  98,  99],
#         ...,
#         [ 51,  51,  51],
#         [ 52,  51,  50],
#         [ 55,  54,  51]],
#
#        [[ 88,  96,  97],
#         [ 89,  97,  98],
#         [ 89,  97,  98],
#         ...,
#         [ 50,  49,  48],
#         [ 51,  50,  49],
#         [ 53,  51,  50]],
#
#        [[ 88,  94,  96],
#         [ 88,  94,  96],
#         [ 87,  93,  95],
#         ...,
#         [ 52,  49,  47],
#         [ 52,  50,  49],
#         [ 52,  50,  50]],
#
#        ...,
#
#        [[ 96, 173, 135],
#         [ 97, 173, 133],
#         [ 97, 172, 129],
#         ...,
#         [ 60,  55,  54],
#         [ 59,  55,  53],
#         [ 58,  55,  53]],
#
#        [[ 94, 174, 134],
#         [ 96, 174, 133],
#         [ 99, 174, 133],
#         ...,
#         [ 60,  55,  53],
#         [ 59,  56,  52],
#         [ 58,  56,  52]],
#
#        [[ 93, 175, 133],
#         [ 95, 174, 133],
#         [ 99, 173, 134],
#         ...,
#         [ 60,  56,  52],
#         [ 60,  57,  53],
#         [ 60,  58,  54]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.9169999975711107, 'inference': 44.697499834001064, 'postprocess': 1.1494001373648643}]
#
# 0: 480x640 1 person, 1 tie, 44.5ms
# Speed: 0.8ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 88,  96,  95],
#         [ 88,  96,  95],
#         [ 90,  98,  97],
#         ...,
#         [ 59,  62,  54],
#         [ 52,  54,  45],
#         [ 52,  53,  44]],
#
#        [[ 88,  97,  95],
#         [ 88,  96,  95],
#         [ 90,  97,  96],
#         ...,
#         [ 54,  55,  48],
#         [ 50,  51,  44],
#         [ 52,  52,  45]],
#
#        [[ 87,  96,  93],
#         [ 88,  96,  93],
#         [ 89,  95,  94],
#         ...,
#         [ 54,  52,  47],
#         [ 51,  50,  46],
#         [ 50,  50,  47]],
#
#        ...,
#
#        [[ 97, 174, 130],
#         [ 98, 174, 129],
#         [100, 175, 128],
#         ...,
#         [ 62,  57,  56],
#         [ 62,  58,  58],
#         [ 60,  56,  57]],
#
#        [[ 95, 174, 131],
#         [ 97, 175, 131],
#         [ 99, 175, 130],
#         ...,
#         [ 61,  56,  54],
#         [ 62,  58,  57],
#         [ 61,  58,  57]],
#
#        [[ 96, 175, 132],
#         [ 97, 176, 133],
#         [ 99, 176, 132],
#         ...,
#         [ 60,  55,  52],
#         [ 62,  58,  56],
#         [ 62,  59,  58]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.8471999317407608, 'inference': 44.518900103867054, 'postprocess': 0.5010999739170074}]
#
# 0: 480x640 1 person, 1 tie, 48.7ms
# Speed: 1.1ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 90,  97,  96],
#         [ 91,  97,  97],
#         [ 93,  95,  98],
#         ...,
#         [ 59,  68,  68],
#         [ 53,  59,  58],
#         [ 48,  53,  52]],
#
#        [[ 91,  97,  96],
#         [ 92,  97,  96],
#         [ 94,  96,  98],
#         ...,
#         [ 57,  63,  63],
#         [ 52,  55,  55],
#         [ 51,  53,  53]],
#
#        [[ 91,  96,  95],
#         [ 91,  95,  94],
#         [ 93,  95,  96],
#         ...,
#         [ 54,  54,  55],
#         [ 53,  51,  53],
#         [ 55,  53,  55]],
#
#        ...,
#
#        [[ 99, 174, 129],
#         [ 98, 173, 131],
#         [ 96, 172, 133],
#         ...,
#         [ 60,  55,  53],
#         [ 62,  56,  55],
#         [ 63,  55,  55]],
#
#        [[ 98, 173, 128],
#         [ 99, 173, 130],
#         [ 97, 172, 133],
#         ...,
#         [ 59,  55,  54],
#         [ 62,  58,  57],
#         [ 62,  58,  57]],
#
#        [[ 98, 173, 128],
#         [ 99, 173, 130],
#         [ 98, 172, 133],
#         ...,
#         [ 56,  53,  52],
#         [ 59,  56,  55],
#         [ 60,  57,  56]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 1.1204001493752003, 'inference': 48.71820006519556, 'postprocess': 0.5246000364422798}]
#
# 0: 480x640 1 person, 1 tie, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 88,  96,  99],
#         [ 89,  96,  99],
#         [ 92,  95,  99],
#         ...,
#         [ 55,  64,  65],
#         [ 55,  61,  60],
#         [ 51,  55,  53]],
#
#        [[ 89,  96,  98],
#         [ 90,  96,  98],
#         [ 92,  96,  98],
#         ...,
#         [ 54,  59,  61],
#         [ 52,  56,  57],
#         [ 48,  52,  51]],
#
#        [[ 87,  94,  94],
#         [ 88,  93,  95],
#         [ 90,  94,  96],
#         ...,
#         [ 53,  53,  56],
#         [ 50,  50,  52],
#         [ 49,  50,  51]],
#
#        ...,
#
#        [[ 97, 174, 129],
#         [ 96, 173, 130],
#         [ 96, 171, 132],
#         ...,
#         [ 60,  55,  54],
#         [ 58,  52,  50],
#         [ 57,  50,  48]],
#
#        [[ 99, 174, 129],
#         [ 97, 172, 129],
#         [ 96, 171, 132],
#         ...,
#         [ 58,  54,  53],
#         [ 56,  52,  51],
#         [ 56,  51,  50]],
#
#        [[ 99, 174, 129],
#         [ 99, 173, 130],
#         [ 98, 172, 133],
#         ...,
#         [ 57,  54,  53],
#         [ 55,  52,  51],
#         [ 55,  52,  51]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.9640001226216555, 'inference': 39.079700130969286, 'postprocess': 0.4920999053865671}]
#
# 0: 480x640 1 person, 1 tie, 37.3ms
# Speed: 0.9ms preprocess, 37.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 89,  95,  94],
#         [ 91,  97,  95],
#         [ 91,  99,  95],
#         ...,
#         [ 57,  62,  64],
#         [ 48,  55,  54],
#         [ 43,  51,  50]],
#
#        [[ 90,  97,  96],
#         [ 91,  97,  96],
#         [ 91,  98,  95],
#         ...,
#         [ 54,  58,  60],
#         [ 48,  53,  52],
#         [ 46,  51,  50]],
#
#        [[ 88,  94,  95],
#         [ 89,  95,  95],
#         [ 89,  94,  93],
#         ...,
#         [ 51,  51,  54],
#         [ 50,  50,  50],
#         [ 51,  50,  49]],
#
#        ...,
#
#        [[ 94, 175, 130],
#         [ 94, 173, 129],
#         [ 95, 172, 131],
#         ...,
#         [ 59,  55,  53],
#         [ 62,  57,  55],
#         [ 64,  59,  57]],
#
#        [[ 94, 172, 131],
#         [ 94, 172, 131],
#         [ 92, 171, 130],
#         ...,
#         [ 59,  56,  54],
#         [ 60,  56,  54],
#         [ 61,  57,  56]],
#
#        [[ 96, 173, 133],
#         [ 94, 172, 132],
#         [ 93, 172, 131],
#         ...,
#         [ 57,  56,  53],
#         [ 58,  55,  54],
#         [ 59,  55,  54]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.8783000521361828, 'inference': 37.27110009640455, 'postprocess': 0.5975000094622374}]
#
# 0: 480x640 1 person, 1 tie, 55.2ms
# Speed: 0.9ms preprocess, 55.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 89,  97,  92],
#         [ 91,  99,  92],
#         [ 91,  99,  90],
#         ...,
#         [ 55,  61,  63],
#         [ 51,  57,  57],
#         [ 49,  54,  53]],
#
#        [[ 90,  97,  93],
#         [ 91,  99,  93],
#         [ 91,  98,  90],
#         ...,
#         [ 54,  58,  60],
#         [ 50,  53,  53],
#         [ 48,  52,  51]],
#
#        [[ 89,  95,  91],
#         [ 90,  96,  92],
#         [ 89,  95,  90],
#         ...,
#         [ 51,  52,  53],
#         [ 48,  49,  49],
#         [ 48,  49,  49]],
#
#        ...,
#
#        [[ 92, 172, 129],
#         [ 93, 173, 130],
#         [ 93, 173, 130],
#         ...,
#         [ 61,  56,  54],
#         [ 61,  57,  55],
#         [ 62,  59,  55]],
#
#        [[ 93, 172, 129],
#         [ 94, 173, 130],
#         [ 93, 173, 131],
#         ...,
#         [ 58,  55,  54],
#         [ 59,  56,  55],
#         [ 59,  58,  55]],
#
#        [[ 95, 173, 130],
#         [ 95, 174, 131],
#         [ 95, 174, 133],
#         ...,
#         [ 58,  55,  55],
#         [ 58,  56,  55],
#         [ 57,  57,  55]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.9144998621195555, 'inference': 55.17780012451112, 'postprocess': 0.9351999033242464}]
#
# 0: 480x640 1 person, 1 tie, 42.4ms
# Speed: 0.9ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 87,  99,  94],
#         [ 87,  99,  94],
#         [ 88, 100,  95],
#         ...,
#         [ 56,  62,  63],
#         [ 53,  56,  56],
#         [ 50,  52,  52]],
#
#        [[ 86,  97,  94],
#         [ 87,  98,  95],
#         [ 88,  99,  96],
#         ...,
#         [ 55,  59,  60],
#         [ 52,  54,  54],
#         [ 51,  52,  52]],
#
#        [[ 86,  96,  94],
#         [ 87,  97,  95],
#         [ 89,  98,  96],
#         ...,
#         [ 50,  52,  52],
#         [ 52,  52,  52],
#         [ 54,  53,  53]],
#
#        ...,
#
#        [[ 94, 174, 131],
#         [ 97, 174, 133],
#         [ 98, 172, 133],
#         ...,
#         [ 65,  60,  59],
#         [ 65,  60,  59],
#         [ 61,  56,  55]],
#
#        [[ 94, 172, 131],
#         [ 96, 173, 133],
#         [ 98, 172, 134],
#         ...,
#         [ 63,  60,  60],
#         [ 63,  58,  59],
#         [ 61,  56,  57]],
#
#        [[ 93, 171, 130],
#         [ 96, 173, 133],
#         [ 99, 173, 135],
#         ...,
#         [ 60,  57,  58],
#         [ 60,  56,  57],
#         [ 61,  56,  57]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.9119000751525164, 'inference': 42.38920006901026, 'postprocess': 0.767500139772892}]
#
# ...
# obb: None
# orig_img: array([[[ 89, 201, 143],
#         [ 88, 200, 142],
#         [ 88, 200, 143],
#         ...,
#         [ 62,  65,  63],
#         [ 61,  66,  62],
#         [ 62,  69,  63]],
#
#        [[ 91, 201, 143],
#         [ 89, 200, 143],
#         [ 89, 199, 143],
#         ...,
#         [ 62,  65,  63],
#         [ 61,  66,  62],
#         [ 61,  67,  62]],
#
#        [[ 93, 200, 144],
#         [ 91, 199, 143],
#         [ 90, 199, 144],
#         ...,
#         [ 62,  65,  64],
#         [ 61,  66,  64],
#         [ 62,  68,  64]],
#
#        ...,
#
#        [[ 77, 178, 123],
#         [ 78, 179, 124],
#         [ 78, 178, 125],
#         ...,
#         [ 66,  69,  76],
#         [ 68,  72,  77],
#         [ 64,  69,  74]],
#
#        [[ 74, 177, 119],
#         [ 75, 178, 120],
#         [ 77, 178, 123],
#         ...,
#         [ 72,  74,  84],
#         [ 71,  74,  83],
#         [ 66,  69,  77]],
#
#        [[ 71, 176, 116],
#         [ 74, 178, 118],
#         [ 77, 179, 121],
#         ...,
#         [ 88,  90, 101],
#         [ 79,  81,  92],
#         [ 67,  69,  80]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 1.0292998049408197, 'inference': 50.977100152522326, 'postprocess': 0.8117998950183392}]
#
# 0: 480x640 1 person, 47.9ms
# Speed: 1.1ms preprocess, 47.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 89, 199, 140],
#         [ 90, 200, 142],
#         [ 89, 199, 143],
#         ...,
#         [ 63,  64,  61],
#         [ 62,  64,  62],
#         [ 63,  66,  64]],
#
#        [[ 92, 200, 144],
#         [ 92, 200, 144],
#         [ 90, 200, 145],
#         ...,
#         [ 64,  66,  63],
#         [ 63,  66,  63],
#         [ 64,  67,  65]],
#
#        [[ 94, 199, 145],
#         [ 93, 199, 145],
#         [ 90, 199, 144],
#         ...,
#         [ 63,  66,  63],
#         [ 63,  68,  64],
#         [ 64,  69,  65]],
#
#        ...,
#
#        [[ 78, 176, 120],
#         [ 79, 178, 123],
#         [ 79, 180, 125],
#         ...,
#         [ 67,  72,  74],
#         [ 66,  71,  73],
#         [ 62,  68,  70]],
#
#        [[ 78, 176, 123],
#         [ 79, 177, 124],
#         [ 80, 176, 126],
#         ...,
#         [ 72,  75,  79],
#         [ 70,  74,  79],
#         [ 68,  73,  79]],
#
#        [[ 76, 174, 122],
#         [ 78, 174, 124],
#         [ 80, 174, 126],
#         ...,
#         [ 86,  87,  93],
#         [ 76,  79,  87],
#         [ 70,  74,  83]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 1.074699917808175, 'inference': 47.91520000435412, 'postprocess': 0.7408999372273684}]
#
# 0: 480x640 1 person, 45.6ms
# Speed: 0.9ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 92, 202, 141],
#         [ 90, 201, 141],
#         [ 88, 200, 140],
#         ...,
#         [ 62,  67,  69],
#         [ 64,  67,  68],
#         [ 67,  68,  68]],
#
#        [[ 92, 202, 143],
#         [ 91, 201, 142],
#         [ 90, 200, 141],
#         ...,
#         [ 60,  66,  65],
#         [ 63,  67,  66],
#         [ 66,  68,  66]],
#
#        [[ 92, 202, 143],
#         [ 92, 201, 143],
#         [ 93, 200, 143],
#         ...,
#         [ 61,  68,  64],
#         [ 64,  69,  65],
#         [ 66,  69,  64]],
#
#        ...,
#
#        [[ 80, 176, 122],
#         [ 81, 176, 125],
#         [ 82, 176, 128],
#         ...,
#         [ 62,  72,  73],
#         [ 64,  72,  74],
#         [ 63,  69,  71]],
#
#        [[ 79, 175, 121],
#         [ 82, 177, 124],
#         [ 84, 176, 128],
#         ...,
#         [ 67,  77,  77],
#         [ 68,  74,  76],
#         [ 68,  72,  74]],
#
#        [[ 77, 175, 119],
#         [ 81, 176, 123],
#         [ 84, 175, 127],
#         ...,
#         [ 79,  89,  89],
#         [ 72,  77,  78],
#         [ 69,  71,  72]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.9438998531550169, 'inference': 45.59509991668165, 'postprocess': 0.5793999880552292}]
#
# 0: 480x640 1 person, 42.7ms
# Speed: 0.9ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 98, 201, 144],
#         [ 95, 200, 143],
#         [ 90, 201, 143],
#         ...,
#         [ 68,  69,  66],
#         [ 67,  69,  63],
#         [ 67,  70,  62]],
#
#        [[ 98, 199, 143],
#         [ 96, 200, 143],
#         [ 91, 201, 143],
#         ...,
#         [ 67,  68,  65],
#         [ 67,  69,  64],
#         [ 67,  69,  63]],
#
#        [[ 99, 199, 143],
#         [ 97, 199, 143],
#         [ 93, 200, 144],
#         ...,
#         [ 67,  67,  64],
#         [ 67,  68,  65],
#         [ 67,  68,  65]],
#
#        ...,
#
#        [[ 79, 177, 120],
#         [ 78, 176, 119],
#         [ 79, 177, 120],
#         ...,
#         [ 70,  71,  75],
#         [ 70,  73,  77],
#         [ 66,  72,  75]],
#
#        [[ 80, 175, 121],
#         [ 80, 175, 120],
#         [ 82, 178, 121],
#         ...,
#         [ 75,  74,  80],
#         [ 71,  71,  77],
#         [ 70,  72,  77]],
#
#        [[ 81, 174, 122],
#         [ 82, 176, 122],
#         [ 83, 178, 121],
#         ...,
#         [ 92,  91,  98],
#         [ 81,  80,  87],
#         [ 77,  76,  82]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.9063000325113535, 'inference': 42.712500086054206, 'postprocess': 0.6502000615000725}]
#
# 0: 480x640 1 person, 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 97, 199, 140],
#         [ 95, 200, 142],
#         [ 91, 200, 144],
#         ...,
#         [ 73,  65,  65],
#         [ 72,  64,  64],
#         [ 74,  65,  65]],
#
#        [[ 98, 200, 141],
#         [ 97, 201, 143],
#         [ 92, 200, 144],
#         ...,
#         [ 72,  67,  66],
#         [ 73,  67,  66],
#         [ 75,  67,  67]],
#
#        [[ 98, 202, 142],
#         [ 97, 201, 143],
#         [ 94, 200, 143],
#         ...,
#         [ 69,  66,  65],
#         [ 71,  67,  66],
#         [ 73,  68,  67]],
#
#        ...,
#
#        [[ 77, 176, 124],
#         [ 78, 176, 123],
#         [ 79, 177, 123],
#         ...,
#         [ 69,  71,  75],
#         [ 72,  73,  77],
#         [ 70,  71,  75]],
#
#        [[ 79, 175, 121],
#         [ 81, 176, 122],
#         [ 82, 177, 122],
#         ...,
#         [ 74,  76,  80],
#         [ 72,  74,  78],
#         [ 72,  74,  78]],
#
#        [[ 80, 174, 119],
#         [ 82, 175, 120],
#         [ 84, 177, 122],
#         ...,
#         [ 84,  86,  90],
#         [ 75,  78,  82],
#         [ 73,  76,  80]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 1.374499872326851, 'inference': 41.30630008876324, 'postprocess': 0.5065000150352716}]
#
# 0: 480x640 1 person, 36.4ms
# Speed: 0.9ms preprocess, 36.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 96, 199, 147],
#         [ 94, 200, 147],
#         [ 92, 201, 146],
#         ...,
#         [ 72,  64,  61],
#         [ 72,  65,  62],
#         [ 73,  67,  64]],
#
#        [[ 98, 200, 146],
#         [ 96, 200, 146],
#         [ 93, 200, 144],
#         ...,
#         [ 72,  65,  63],
#         [ 72,  67,  65],
#         [ 72,  68,  65]],
#
#        [[101, 200, 144],
#         [100, 200, 144],
#         [ 96, 200, 143],
#         ...,
#         [ 70,  66,  65],
#         [ 70,  67,  65],
#         [ 70,  68,  66]],
#
#        ...,
#
#        [[ 79, 174, 126],
#         [ 80, 176, 126],
#         [ 81, 177, 126],
#         ...,
#         [ 70,  74,  76],
#         [ 71,  74,  78],
#         [ 68,  71,  75]],
#
#        [[ 79, 173, 123],
#         [ 81, 175, 124],
#         [ 82, 177, 123],
#         ...,
#         [ 72,  75,  76],
#         [ 71,  75,  77],
#         [ 70,  73,  77]],
#
#        [[ 81, 174, 123],
#         [ 82, 175, 123],
#         [ 82, 176, 121],
#         ...,
#         [ 83,  87,  86],
#         [ 77,  80,  82],
#         [ 74,  77,  81]]], shape=(480, 640, 3), dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'C:\\Users\\John Gabriel\\Downloads\\Paid Course Materials\\Deep Learning Tamil\\Chapter 17 - Object Detection\\OpenCV-YOLO\\runs\\detect\\predict'
# speed: {'preprocess': 0.9221998043358326, 'inference': 36.448099883273244, 'postprocess': 0.5131000652909279}]
#
# 0: 480x640 1 person, 40.7ms
# Speed: 0.9ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# # TASK is to understand the code line by line - What it does. --> This is what real-time Challenge and how it works.
#
# They can use chatgpt for that. Even Create an image

# %% [markdown]
# # THE END!
