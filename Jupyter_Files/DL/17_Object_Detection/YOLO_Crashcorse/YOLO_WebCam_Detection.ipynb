# %% [markdown]
# # WebCam Detection & Prediction using YOLO
#
# **Note:**
# 1. This script is for Pre-defined Classes Prediction - Not for *Custom Data*
# 2. So take predefined Models - which has predefined weights for our prediction, but it will predict the same items.

# %%
import cv2

print(cv2.__file__)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\cv2\__init__.py

# %%
#pip install ultralytics
# !pip uninstall ultralytics -y
# Out:
# WARNING: Skipping ultralytics as it is not installed.

# %%
import cv2
from ultralytics import YOLO

model = YOLO("yolo26n.pt")

video = cv2.VideoCapture(0)

while True:
    success, frame = video.read()
    if success == True:
        results = model(frame)
        print(results)
        
        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                confidence = float(box.conf[0])
                class_id = int(box.cls[0])
                class_name = model.names[class_id]
                cv2.rectangle(frame,(x1, y1),(x2, y2),(0, 255, 0),3)
                label = f"{class_name} {confidence:.2f}"
                cv2.putText(frame,label,(x1, y1 - 10),cv2.FONT_HERSHEY_SIMPLEX,0.7,(0, 255, 0),2) # Put Label Above Box

        cv2.imshow("YOLO Webcam Detection", frame)
        key = cv2.waitKey(delay = 1)
        if key == 113 or key == 81:
            break
   
    else:
        print("Video Stopped")

video.release()
cv2.destroyAllWindows()
# Out:
# Creating new Ultralytics Settings v0.0.7 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Lenovo\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# 0: 480x640 1 person, 168.4ms
# Speed: 9.6ms preprocess, 168.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# depth: None
# keypoints: None
# masks: None
# ...

# %% [markdown]
# # TASK is to understand the code line by line - What it does. --> This is what real-time Challenge and how it works.
#
# They can use chatgpt for that. Even Create an image

# %% [markdown]
# # THE END!
