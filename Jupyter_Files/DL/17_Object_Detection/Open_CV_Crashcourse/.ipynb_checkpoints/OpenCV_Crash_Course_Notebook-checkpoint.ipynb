# %% [markdown]
# # Tasks to be Performed:
# 1. Single Object Detection
# 2. Multiple Object Detection
# 3. Webcam/CCTV Detection

# %% [markdown]
# ## 10 Step Framework for OpenCV Object Detection:
# * Step 1: Import libraries
# * Step 2: Import Model
# * Step 3: Import Image/Video
# * Step 4: Convert this into GreyScale
# * Step 5: Use MultiscaleDetector to get the position co-ordinates
# * Step 6: Use Looping statement to draw the Rectangular bounding box as much objects we get
# * Step 7: Display the Image
# * Step 8: Drop the Waitkey to Pause the Program for a given second, refresh it again and again, and get the Key to close
# * Step 9: Kill the video/image frame
# * Step 10: Close all the windows

# %% [markdown]
# # 1. Single/Multiple Object Detection

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\john gabriel\appdata\local\programs\python\python310\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\john gabriel\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (2.2.6)
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

front_face_detector = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")
image = cv2.imread("police_multiple_images.jpg")
grey_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
face_detector = front_face_detector.detectMultiScale(grey_image)
print(face_detector)

for x,y,w,h in face_detector:
    cv2.rectangle(grec`y_image,(x,y),(x+w,y+h),(255,0,0),3)
cv2.imshow("image_window",grey_image)
cv2.waitKey()
# Out:
# [[561 250 107 107]
#  [404 258 126 126]
#  [736 354 117 117]]
# -1

# %% [markdown]
# ## 3. CCTV/WebCam Detection

# %%
front_face_detector = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")

video = cv2.VideoCapture(0)

while True:
    success,frame = video.read()
    if success == True:
        grey_image = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
        face_detector = front_face_detector.detectMultiScale(grey_image)
           
        for x,y,w,h in face_detector:
            cv2.rectangle(grey_image,(x,y),(x+w,y+h),(255,0,0),3)
        
        cv2.imshow("image_window",grey_image)
        key = cv2.waitKey(1)
        if key == 81 or key == 113:
            break

video.release()
cv2.destroyAllWindows()

# %% [markdown]
# # The END!!
