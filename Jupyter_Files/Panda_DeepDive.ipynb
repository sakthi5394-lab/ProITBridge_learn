# %% [markdown]
# ## Notes :
# Data Analyse
# 1. Load the data with meaningful object name
# 2. Initial Operation /n
#         1. shape
#        2. isnull(Meaningful Numm Entry
#          3. describe
# 3. Frequent Option 1. Groupby 2. Unique 3. Count/Sum 4. head/tail
#
# Data Cleaning
#     * Ensure the Data Type is non Object for the Numberic/Float Data Series
#     * Index, Slicing and Filtering
# Handling Missing Data:
