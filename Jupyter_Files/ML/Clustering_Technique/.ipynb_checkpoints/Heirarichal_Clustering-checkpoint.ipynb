# %% [markdown]
# ## 1. Import Necessary Library

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.cluster import hierarchy
from sklearn.cluster import AgglomerativeClustering
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot as plt

# %% [markdown]
# ## 2. Data Collection

# %%
college_data = pd.read_csv("college_list.csv")
college_data
# Out:
#                                           College_Name  ...  Infrastructure_Score
# 0     Indian Institute of Technology Madras - Campus 1  ...                     8
# 1    National Institute of Technology Trichy - Camp...  ...                     7
# 2                   Anna University Chennai - Campus 1  ...                     9
# 3                 PSG College of Technology - Campus 1  ...                     8
# 4        Coimbatore Institute of Technology - Campus 1  ...                     9
# ..                                                 ...  ...                   ...
# 495     Thiagarajar College of Engineering - Campus 17  ...                     5
# 496  Bannari Amman Institute of Technology - Campus 17  ...                     7
# 497  Sri Krishna College of Engineering and Technol...  ...                     3
# 498             Sona College of Technology - Campus 17  ...                     6
# ...

# %% [markdown]
# ## 3. Data Understanding

# %%
college_data.shape
# Out:
# (500, 6)

# %%
college_data.isna().sum()
# Out:
# College_Name             0
# Student_Faculty_Ratio    0
# Annual_Fees_INR          0
# Placement_Percentage     0
# Average_Package_LPA      0
# Infrastructure_Score     0
# dtype: int64

# %%
college_data.dtypes
# Out:
# College_Name              object
# Student_Faculty_Ratio      int64
# Annual_Fees_INR            int64
# Placement_Percentage       int64
# Average_Package_LPA      float64
# Infrastructure_Score       int64
# dtype: object

# %%
X = college_data.drop("College_Name",axis=1)

# %% [markdown]
# ## 4. Data Preprocessing

# %%
std_scaller = StandardScaler()

# %%
scalled_X = std_scaller.fit_transform(X)
scalled_X = pd.DataFrame(scalled_X,columns=X.columns)

# %%
scalled_X.mean().round(),scalled_X.std().round()
# Out:
# (Student_Faculty_Ratio    0.0
#  Annual_Fees_INR          0.0
#  Placement_Percentage    -0.0
#  Average_Package_LPA      0.0
#  Infrastructure_Score    -0.0
#  dtype: float64,
#  Student_Faculty_Ratio    1.0
#  Annual_Fees_INR          1.0
#  Placement_Percentage     1.0
#  Average_Package_LPA      1.0
#  Infrastructure_Score     1.0
#  dtype: float64)

# %% [markdown]
# ## 5. Data Preprocessing

# %%
hierarchy.dendrogram(hierarchy.linkage(scalled_X,method='ward'))
plt.show()

# %%
hierarchy.dendrogram(hierarchy.linkage(scalled_X.head(10),method='ward'))
plt.show()

# %% [markdown]
# ## 6. Data Preparation

# %%
Clust_Module = AgglomerativeClustering(n_clusters=3,linkage='ward')

# %%
X["Category"] = Clust_Module.fit_predict(scalled_X)

# %%
college_data["Cluster_Category"] = Clust_Module.fit_predict(scalled_X)

# %%
X
# Out:
#      Student_Faculty_Ratio  Annual_Fees_INR  Placement_Percentage  Average_Package_LPA  Infrastructure_Score  Category
# 0                       14           113042                    59                 9.20                     8         2
# 1                       27           115999                    67                 3.07                     7         0
# 2                       22            47955                    50                 3.40                     9         0
# 3                       18            67841                    43                 4.64                     8         0
# 4                       15           100640                    54                 4.66                     9         0
# ..                     ...              ...                   ...                  ...                   ...       ...
# 495                     17           106323                    56                 9.33                     5         0
# ...

# %%
college_data
# Out:
#                                           College_Name  Student_Faculty_Ratio  ...  Infrastructure_Score  Cluster_Category
# 0     Indian Institute of Technology Madras - Campus 1                     14  ...                     8                 2
# 1    National Institute of Technology Trichy - Camp...                     27  ...                     7                 0
# 2                   Anna University Chennai - Campus 1                     22  ...                     9                 0
# 3                 PSG College of Technology - Campus 1                     18  ...                     8                 0
# 4        Coimbatore Institute of Technology - Campus 1                     15  ...                     9                 0
# ..                                                 ...                    ...  ...                   ...               ...
# 495     Thiagarajar College of Engineering - Campus 17                     17  ...                     5                 0
# ...

# %%
X.describe()
# Out:
#        Student_Faculty_Ratio  Annual_Fees_INR  ...  Infrastructure_Score    Category
# count             500.000000       500.000000  ...             500.00000  500.000000
# mean               18.084000    138763.710000  ...               5.97600    0.576000
# std                 6.683283     63928.678815  ...               2.00486    0.803439
# min                 8.000000     30404.000000  ...               3.00000    0.000000
# 25%                12.000000     82610.500000  ...               4.00000    0.000000
# 50%                18.000000    140290.500000  ...               6.00000    0.000000
# 75%                24.000000    193422.000000  ...               8.00000    1.000000
# max                29.000000    249930.000000  ...               9.00000    2.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# ## Data Mining

# %%
X.groupby(by = "Category").agg("mean")
# Out:
#           Student_Faculty_Ratio  Annual_Fees_INR  Placement_Percentage  Average_Package_LPA  Infrastructure_Score
# Category
# 0                     20.407051    121853.471154             67.278846             6.954583              6.509615
# 1                     17.159091    156795.136364             85.568182             5.565682              3.965909
# 2                     11.650000    175656.000000             59.790000             8.362500              6.080000

# %%
X.groupby(by = "Category").agg(["min","max"])
# Out:
#          Student_Faculty_Ratio     Annual_Fees_INR          ... Average_Package_LPA        Infrastructure_Score
#                            min max             min     max  ...                 min    max                  min max
# Category                                                    ...
# 0                            8  29           30404  249536  ...                2.00  11.99                    3   9
# 1                            8  29           39337  248803  ...                2.09  11.96                    3   9
# 2                            8  20           49065  249930  ...                2.01  11.91                    3   9
#
# [3 rows x 10 columns]

# %%
Module_Category = {0:"Emerging",
                   1:"Mid-Level",
                   2: "Best"}

X["College_Category"] = X["Category"].map(Module_Category)

# %%
X
# Out:
#      Student_Faculty_Ratio  Annual_Fees_INR  Placement_Percentage  ...  Infrastructure_Score  Category  College_Category
# 0                       14           113042                    59  ...                     8         2              Best
# 1                       27           115999                    67  ...                     7         0          Emerging
# 2                       22            47955                    50  ...                     9         0          Emerging
# 3                       18            67841                    43  ...                     8         0          Emerging
# 4                       15           100640                    54  ...                     9         0          Emerging
# ..                     ...              ...                   ...  ...                   ...       ...               ...
# 495                     17           106323                    56  ...                     5         0          Emerging
# ...

# %%
Culuster_X = X.drop(["Category","College_Category"],axis=1)
y = X["Category"]

# %% [markdown]
# ## Prediction

# %%
X_train,X_test,y_train,y_test = train_test_split(Culuster_X,y,shuffle=True,random_state=12,stratify=y,test_size=0.20)

# %%
rf_Module = RandomForestClassifier()

# %%
rf_Module.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_Module.score(X_test,y_test)
# Out:
# 0.92
