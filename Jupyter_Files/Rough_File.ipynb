# %% [markdown]
# ### List Comphrehension

# %%
even_li = [i for i in range(11) if i%2 == 0]
print(even_li)
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
print(__name__)
# Out:
# __main__

# %%
def var_twice(i,lst=[]):
    lst.append(i)
    lst.append(i)
    return lst

print(var_twice(1))
print(var_twice(2))
# Out:
# [1, 1]
# [1, 1, 2, 2]

# %%
srt1 = "Sakthi@gmail.com"
#srt1.index('@')
srt1.index('.')
# Out:
# 12

# %%
print("\N{grinning face}")
# Out:
# 😀

# %%
import base64

text = 'abcd123456789'

text_byte = text.encode("utf-8")
txet_b64 = base64.b64encode(text_byte).decode("utf-8")
print(txet_b64)
# Out:
# YWJjZDEyMzQ1Njc4OQ==

# %%
tb64_str = 'SGVsbG8gV29ybGQh'

byte_tb64 = base64.b64decode(txet_b64)
print(byte_tb64.decode("utf-8"))
# Out:
# abcd123456789
