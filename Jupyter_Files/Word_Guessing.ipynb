# %% [markdown]
# ### Phase 1 : Create the Emplty List with Secrete Word

# %%
print(""" Welcome to the Word Guessing World""")
guessed_word = ["_"]*5
guessed_word[0] = 'S'
guessed_word[4] = 'I'

user_input = input("Enter the Guess Word:")
if user_input.isalpha():
    pass
else:
    print("Please enter the Valid Characters")
final_word = ''.join(guessed_word)
print(f"{final_word}")
print(len(final_word))
# Out:
#  Welcome to the Word Guessing World
# Enter the Guess Word: jbsd151
# Please enter the Valid Characters
# S___I
# 5

# %% [markdown]
# ### Phase 2 : Create the Screted Word Pool

# %%
import pandas as pd

# %%
with open("/MyLearning/Python_WS/ProITBridge/Jupyter_Files/Data_File/Word_Guess_Pool.txt","r") as word_pool:
    word_list= word_pool.read().splitlines()
    dict(word_list[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 with open("/MyLearning/Python_WS/ProITBridge/Jupyter_Files/Data_File/Word_Guess_Pool.txt","r") as word_pool:
#       2     word_list= word_pool.read().splitlines()
# ----> 3     dict(word_list[0])
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
open()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 open()
#
# TypeError: open() missing 1 required positional argument: 'file'
